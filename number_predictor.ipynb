# %% [markdown]
# <a href="https://colab.research.google.com/github/srimjam27/Digit_classifier/blob/main/number_predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
(x_train,y_train),(x_test,y_test)=keras.datasets.mnist.load_data()
# Out:
# ...
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
len(x_train)
# Out:
# 60000

# %%
len(x_test)
# Out:
# 10000

# %%
x_train[0].shape
# Out:
# (28, 28)

# %%
plt.matshow(x_train[0])

# %%
plt.matshow(x_test[0])

# %%
x_train=x_train/255
x_test=x_test/255

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(100,activation='relu'),
    keras.layers.Dense(10,activation='sigmoid')
])

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(x_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2681 - accuracy: 0.9251
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1233 - accuracy: 0.9635
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0866 - accuracy: 0.9743
# Epoch 4/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0663 - accuracy: 0.9796
# Epoch 5/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0526 - accuracy: 0.9833
# Epoch 6/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0427 - accuracy: 0.9867
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0345 - accuracy: 0.9893
# Epoch 8/10
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.0281 - accuracy: 0.9915
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0242 - accuracy: 0.9927
# Epoch 10/10
# ...

# %%
model.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0824 - accuracy: 0.9750
# [0.08237104117870331, 0.9750000238418579]

# %%
for i in range(1069,1079):
  plt.matshow(x_test[i])
  plt.show()
  true_pred=model.predict(x_test)
  print(f"Model predicted it to be {np.argmax(true_pred[i])}\nWhile true value is {y_test[i]}")
# Out:
# 313/313 [==============================] - 1s 2ms/step
# Model predicted it to be 3
# While true value is 3
# 313/313 [==============================] - 1s 2ms/step
# Model predicted it to be 5
# While true value is 5
# 313/313 [==============================] - 1s 2ms/step
# Model predicted it to be 7
# While true value is 7
# 313/313 [==============================] - 1s 2ms/step
# Model predicted it to be 3
# While true value is 3
# 313/313 [==============================] - 1s 2ms/step
# Model predicted it to be 5
# While true value is 5
# 313/313 [==============================] - 0s 2ms/step
# Model predicted it to be 8
# While true value is 8
# 313/313 [==============================] - 1s 2ms/step
# Model predicted it to be 1
# While true value is 1
# 313/313 [==============================] - 1s 2ms/step
# Model predicted it to be 2
# While true value is 2
# 313/313 [==============================] - 1s 2ms/step
# Model predicted it to be 4
# While true value is 4
# ...
